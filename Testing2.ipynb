# %%
from bs4 import BeautifulSoup
import urllib3
import csv
from datetime import datetime

# %%
from requests import get
url = 'http://oregonhospitalguide.org/hospitals/mid-columbia-medical-center/#procedure-costs'
response = get(url)

# %%
response.text[:500]
# Out:
# '<!doctype html>\r\n<html>\r\n    <head>\r\n    <meta charset="utf-8">\r\n    <meta http-equiv="X-UA-Compatible" content="IE=edge">\r\n    <title>Mid-Columbia Medical Center | Quality Scores</title>\r\n    <meta name="viewport" content="width=device-width, initial-scale=1">\r\n\t<meta name="keywords" content="" /> \r\n\t<meta name="description" content="Discover the latest medical procedure costs, hospital quality scores, & patient satisfaction ratings for Mid-Columbia Medical Center." /> \r\n    <meta name="msvalid'

# %%
html = BeautifulSoup(response.text, 'html.parser')
type(html)
# Out:
# bs4.BeautifulSoup

# %%
html.contents
# Out:
# ['doctype html', '\n', <html>
#  <head>
#  <meta charset="utf-8"/>
#  <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#  <title>Mid-Columbia Medical Center | Quality Scores</title>
#  <meta content="width=device-width, initial-scale=1" name="viewport"/>
#  <meta content="" name="keywords">
#  <meta content="Discover the latest medical procedure costs, hospital quality scores, &amp; patient satisfaction ratings for Mid-Columbia Medical Center." name="description">
#  <meta content="8AE3A611BDF502E3E412AC06236E3FA4" name="msvalidate.01">
#  <style type="text/css">
#  	a {
#  		text-decoration: none;
#  		color: #005CAB;
#  	}
#  	body{
#  		margin:0;
#  	}
#  	.fit-img {
#  		display: block;
#  		max-width: 100%;
#  		max-height: 100%;
#  	}
#  	.site-header {
#  		position: relative;
#  		background: #FFF;
#  		max-width: 960px;
#  		margin: 0 auto;
#  	}
#      .main-nav-wrap{
#
#  	}
#  	.main-nav {
#  		list-style: none;
#  		z-index: 1;
#  	}
# ...

# %%
procedure_containers = html.find_all('div', class_='measure-title')
print(type(procedure_containers))
print(len(procedure_containers))
# Out:
# <class 'bs4.element.ResultSet'>
# 59

# %%
procedures = []
for i in range (0, len(procedure_containers)):
    procedures.append(procedure_containers[i].text)
print(procedures)
# Out:
# ['Arthrography ?', 'Carpal Tunnel ?', 'Colonoscopy ?', 'Cystoscopy Lithotripsy ?', 'Gallbladder ?', 'Hernia Repair ?', 'Shoulder Arthroscopy ?', 'Upper Endoscopy ?', 'Bone Study ?', 'Cardiovascular: Echocardiography ?', 'Cardiovascular: Electrocardiography ?', 'CT scan with contrast: Abdomen/GI ?', 'CT scan with contrast: Chest ?', 'CT scan with contrast: Head and Neck ?', 'CT scan: Abdomen/GI ?', 'Mammography ?', 'MRI with contrast: Head and Neck ?', 'MRI: Extremities ?', 'MRI: Spine ?', 'Ultrasound ?', 'X-ray: Abdomen/GI ?', 'X-ray: Chest ?', 'X-ray: Extremities ?', 'X-ray: Spine ?', 'Newborn care without complications ?', 'Ultrasound: Obstetrical ?', 'Chemotherapy: Injection ?', 'Chemotherapy: IV infusion ?', 'Radiation Treatment: Consult ?', 'Radiation Treatment: Delivery ?', 'Radiation Treatment: Devices ?', 'Radiation Treatment: Dosimetry ?', 'Radiation Treatment: IMRT ?', 'Radiation Treatment: Simulations & Film ?', 'Readmitted Within 30 Days After Heart Attack ?', 'Death With
# ...

# %%
cost_containers = html.find_all('div', class_='measure-title')
print(type(procedure_containers))
print(len(procedure_containers))
costs = []
for i in range (0, len(procedure_containers)):
    procedures.append(procedure_containers[i].text)
print(procedures)
