# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib

# %%
pd.set_option('display.max_columns', 500)

# %%
df = pd.read_csv('OR_hos_prices.csv')

# %%
df.describe()
# Out:
#        Cardiovascular: Electrophysiology  Thyroidectomy  \
# count                            6.00000       6.000000
# mean                         44269.50000   14791.833333
# std                           7643.32011    1889.779396
# min                          38063.00000   12222.000000
# 25%                          38908.75000   13352.250000
# 50%                          41364.00000   15385.500000
# 75%                          47135.00000   15972.000000
# max                          57677.00000   16916.000000
#
#        Nuclear Medicine: Musculoskeletal  Central Line  Breast Reconstruction  \
# count                          17.000000      6.000000                4.00000
# mean                         1030.588235  32777.666667            17472.25000
# std                           307.455090   8405.183940             2793.81834
# min                           504.000000  25246.000000            14263.00000
# ...

# %%
df.head()
# Out:
#                                Unnamed: 0  Cardiovascular: Electrophysiology  \
# 0             Mid-Columbia Medical Center                                NaN
# 1      Asante Three Rivers Medical Center                                NaN
# 2       Asante Ashland Community Hospital                                NaN
# 3           Legacy Emanuel Medical Center                            48813.0
# 4  Good Samaritan Regional Medical Center                            40627.0
#
#    Thyroidectomy  Nuclear Medicine: Musculoskeletal  Central Line  \
# 0            NaN                                NaN           NaN
# 1            NaN                             1384.0           NaN
# 2            NaN                                NaN           NaN
# 3        12222.0                                NaN       48628.0
# 4        16109.0                             1082.0       28054.0
#
#    Breast Reconstruction  Arthorcentesis  \
# 0                    NaN             NaN
# ...

# %%
hospitals = df[df.columns[0]].values

# %% [markdown]
# No hospital has all NaNs. No procedure is entirely filled in with data

# %%
df.dropna(axis=0, how='all')
# Out:
#                                            Unnamed: 0  \
# 0                         Mid-Columbia Medical Center
# 1                  Asante Three Rivers Medical Center
# 2                   Asante Ashland Community Hospital
# 3                       Legacy Emanuel Medical Center
# 4              Good Samaritan Regional Medical Center
# 5                Asante Rogue Regional Medical center
# 6                  McKenzie-Willamette Medical Center
# 7                                  Tuality Healthcare
# 8                   Samaritan Albany General Hospital
# 9                    Legacy Mount Hood Medical Center
# 10                               Mercy Medical Center
# 11                    Legacy Silverton Medical Center
# 12  PeaceHealth Sacred Heart Medical Center Univer...
# 13                  Providence Newberg Medical Center
# 14            Providence Willamette Falls Medical Ctr
# 15                                 St Charles Redmond
# ...

# %%
sns.set()

# %%
sns.boxplot(data=df.ix[:, 0:50])
fig = matplotlib.pyplot.gcf()
fig.set_size_inches(18.5, 10.5)
plt.title('')
plt.ylabel('Procedure cost ( USD $)')
plt.xticks(rotation='vertical')
plt.yticks(np.arange(0, 80000, step=5000))
plt.savefig('procedure_cost_boxplot.png')
plt.show()
# Out:
# C:\Users\asus\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.

# %%
sns.boxplot(data=df.ix[:, 70:71])
fig = matplotlib.pyplot.gcf()
plt.ylabel('Procedure cost ( USD $)')
plt.yticks(np.arange(0,30000, step=2500))
plt.xticks([])
#plt.savefig('colonoscopy_cost_boxplot.png')
plt.show()
# Out:
# C:\Users\asus\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.

# %%
sns.boxplot(data=df.ix[:, 63:64])
fig = matplotlib.pyplot.gcf()
plt.title('')
plt.ylabel('Procedure cost ( USD $)')
plt.xticks(rotation='vertical')
plt.savefig('upperendoscopy_cost_boxplot.png')
plt.show()
# Out:
# C:\Users\asus\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.

# %%
sns.boxplot(data=df.ix[:, 37:38])
fig = matplotlib.pyplot.gcf()
plt.title('')
plt.ylabel('Procedure cost ( USD $)')
plt.xticks([])
plt.savefig('coronarybypass_cost_boxplot.png')
plt.show()
# Out:
# C:\Users\asus\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.

# %%
sns.boxplot(y=df['CT scan with contrast: Head and Neck'])

# %%
temp = df.dropna(df)
sns.barplot(df[df.columns[0]], df[df.columns[1]], dropna=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-62-576712d06f48> in <module>()
# ----> 1 sns.barplot(df[df.columns[0]], df[df.columns[1]], dropna=True)
#
# ~\Anaconda3\lib\site-packages\seaborn\categorical.py in barplot(x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge, ax, **kwargs)
#    3152         ax = plt.gca()
#    3153
# -> 3154     plotter.plot(ax, kwargs)
#    3155     return ax
#    3156
#
# ~\Anaconda3\lib\site-packages\seaborn\categorical.py in plot(self, ax, bar_kws)
#    1659     def plot(self, ax, bar_kws):
#    1660         """Make the plot."""
# -> 1661         self.draw_bars(ax, bar_kws)
#    1662         self.annotate_axes(ax)
#    1663         if self.orient == "h":
#
# ~\Anaconda3\lib\site-packages\seaborn\categorical.py in draw_bars(self, ax, kws)
# ...
