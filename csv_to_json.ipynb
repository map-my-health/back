# %%
import pandas as pd

# %%
df = pd.read_csv('addresses_latlong_verified.csv')

# %%
df
# Out:
#     Unnamed: 0 accuracy                                  formatted_address  \
# 0            0  ROOFTOP          1700 E 19th St, The Dalles, OR 97058, USA
# 1            1  ROOFTOP      500 SW Ramsey Ave, Grants Pass, OR 97527, USA
# 2            2  ROOFTOP         9205 SW Barnes Rd, Portland, OR 97225, USA
# 3            3  ROOFTOP               280 Maple St, Ashland, OR 97520, USA
# 4            4  ROOFTOP     2801 N Gantenbein Ave, Portland, OR 97227, USA
# 5            5  ROOFTOP  3181 SW Sam Jackson Park Rd, Portland, OR 9723...
# 6            6  ROOFTOP     3600 NW Samaritan Dr, Corvallis, OR 97330, USA
# 7            7  ROOFTOP          1015 NW 22nd Ave, Portland, OR 97210, USA
# 8            8  ROOFTOP          2825 E Barnett Rd, Medford, OR 97504, USA
# 9            9  ROOFTOP              1460 G St, Springfield, OR 97477, USA
# 10          10  ROOFTOP           335 SE 8th Ave, Hillsboro, OR 97123, USA
# ...

# %%
df.to_json('addresses_latlong_verified.json')
